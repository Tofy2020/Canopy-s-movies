# %% [markdown]
# Canopy’s curated movies
# The steps to perform a holistic analysis of the provided data sets and gather insights to inform future business goals are the following:
# Data set A, contains the list of movie title and platforms where they are streamed.
# Data set B, contains details about the movies such as year, age, runtime, rating(IMDb), directors, genres, country, and language.

# %% [markdown]
# Load and combine the data sets:

# %%
import pandas as pd
# Load data set A
df_a = pd.read_csv('C:/Users/Tofy/Desktop/Scale without Border/Module 6/Final assignment datasets/20220525_movieds.csv')
df_a
# Out:
#                                                    Title  Year  Age  IMDb  \
# 0                                           Trigger Pals  1939  NaN   5.3
# 1             One Way Astronaut: The Mars One Initiative  2017  NaN   NaN
# 2                                             Open Grave  2013  18+   6.2
# 3      Metallica: Kill 'Em All to St. Anger - The Ult...  2006  NaN   NaN
# 4                                        Beyond the Pale  2014  NaN   7.4
# ...                                                  ...   ...  ...   ...
# 15064                                       Holiday Rush  2019   7+   4.8
# 15065                                     Demolition Man  1993  18+   6.7
# 15066                             Düğün Dernek 2: Sünnet  2015  13+   6.4
# 15067                                        Fanney Khan  2018  NaN   4.5
# 15068                                          Off Label  2013  NaN   5.2
#
#       Rotten Tomatoes                      Directors  \
# 0                 NaN                   Sam Newfield
# 1                 NaN                            NaN
# 2                 18%          Gonzalo López-Gallego
# 3                 NaN                            NaN
# 4                 NaN                    Ja-Ann Wang
# ...               ...                            ...
# 15064             NaN                   Leslie Small
# 15065             59%                Marco Brambilla
# 15066             NaN                 Selçuk Aydemir
# 15067             63%                 Atul Manjrekar
# 15068             50%  Donal Mosher,Michael Palmieri
#
#                           Genres                Country Language  Runtime
# 0       Action,Adventure,Western          United States  English     59.0
# 1                            NaN                    NaN      NaN      NaN
# 2        Horror,Mystery,Thriller  United States,Hungary  English    102.0
# 3                            NaN                    NaN      NaN      NaN
# 4                    Short,Drama          United States  English     11.0
# ...                          ...                    ...      ...      ...
# 15064             Comedy,Romance          United States  English     92.0
# 15065     Action,Sci-Fi,Thriller          United States  English    115.0
# 15066                     Comedy                 Turkey  Turkish    112.0
# 15067         Comedy,Drama,Music                  India      NaN    130.0
# 15068  Documentary,Drama,History          United States  English     80.0
#
# [15069 rows x 10 columns]

# %%
# Load data set B
df_b = pd.read_csv('C:/Users/Tofy/Desktop/Scale without Border/Module 6/Final assignment datasets/20220620_movie2ds.csv')
df_b
# Out:
#           ID                                          Title  Netflix  Hulu  \
# 0      13825  The Jungle Book: Search for the Lost Treasure        0     0
# 1      15943           Vellaiya Irukiravan Poi Solla Maatan        0     0
# 2       6233                                  Hollows Grove        0     0
# 3      16194                              Web of the Spider        0     0
# 4       7870                                 Life in Danger        0     0
# ...      ...                                            ...      ...   ...
# 15064   2358                                     Bonanza TV        0     0
# 15065   3672                                          Darra        1     0
# 15066   1902                                  Bennett's War        1     0
# 15067   6894                              Is Paris Burning?        0     0
# 15068  10666                                      Reparando        0     0
#
#        Prime Video  Disney+
# 0                1        0
# 1                1        0
# 2                1        0
# 3                1        0
# 4                1        0
# ...            ...      ...
# 15064            1        0
# 15065            0        0
# 15066            0        0
# 15067            1        0
# 15068            1        0
#
# [15069 rows x 6 columns]

# %%
# Merge both data sets based on the movie name
movies_df = pd.merge(df_a, df_b, on='Title')
movies_df
# Out:
#                                                    Title  Year  Age  IMDb  \
# 0                                           Trigger Pals  1939  NaN   5.3
# 1                                             Open Grave  2013  18+   6.2
# 2      Metallica: Kill 'Em All to St. Anger - The Ult...  2006  NaN   NaN
# 3                                        Beyond the Pale  2014  NaN   7.4
# 4                                            White Tiger  1996  13+   5.0
# ...                                                  ...   ...  ...   ...
# 13418                            The High Cost of Living  2011  13+   6.8
# 13419                                       Holiday Rush  2019   7+   4.8
# 13420                                     Demolition Man  1993  18+   6.7
# 13421                                        Fanney Khan  2018  NaN   4.5
# 13422                                          Off Label  2013  NaN   5.2
#
#       Rotten Tomatoes                      Directors  \
# 0                 NaN                   Sam Newfield
# 1                 18%          Gonzalo López-Gallego
# 2                 NaN                            NaN
# 3                 NaN                    Ja-Ann Wang
# 4                 NaN             Karen Shakhnazarov
# ...               ...                            ...
# 13418             53%                   Deborah Chow
# 13419             NaN                   Leslie Small
# 13420             59%                Marco Brambilla
# 13421             63%                 Atul Manjrekar
# 13422             50%  Donal Mosher,Michael Palmieri
#
#                              Genres                Country  \
# 0          Action,Adventure,Western          United States
# 1           Horror,Mystery,Thriller  United States,Hungary
# 2                               NaN                    NaN
# 3                       Short,Drama          United States
# 4      Action,Adventure,Fantasy,War                 Russia
# ...                             ...                    ...
# 13418                         Drama                 Canada
# 13419                Comedy,Romance          United States
# 13420        Action,Sci-Fi,Thriller          United States
# 13421            Comedy,Drama,Music                  India
# 13422     Documentary,Drama,History          United States
#
#                        Language  Runtime     ID  Netflix  Hulu  Prime Video  \
# 0                       English     59.0  15592        0     0            1
# 1                       English    102.0   9730        0     0            1
# 2                           NaN      NaN   8681        0     0            1
# 3                       English     11.0   1987        0     0            1
# 4                Russian,German    104.0  16377        0     0            1
# ...                         ...      ...    ...      ...   ...          ...
# 13418  English,French,Cantonese     92.0  13673        0     0            1
# 13419                   English     92.0   6228        1     0            0
# 13420                   English    115.0   3911        0     1            0
# 13421                       NaN    130.0   4797        0     0            1
# 13422                   English     80.0   9607        0     0            1
#
#        Disney+
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 13418        0
# 13419        0
# 13420        0
# 13421        0
# 13422        0
#
# [13423 rows x 15 columns]

# %% [markdown]
# 2. Handling missing data and cleaning:

# %%
# Remove rows with missing data
movies_df = movies_df.dropna()

# %%
# Convert the year column to integers
movies_df['Year'] = movies_df['Year'].astype(int)
# Out:
# C:\Users\Tofy\AppData\Local\Temp\ipykernel_22504\3745908.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_df['Year'] = movies_df['Year'].astype(int)

# %%
# Remove any duplicate rows
movies_df = movies_df.drop_duplicates()

# %% [markdown]
# 3. Find the top 20 movies in each genre available in French language:

# %%
# Group the data frame by genre and language
grouped = movies_df.groupby(['Genres', 'Language'])

# %%
# Create a new data frame to store the top 20 movies for each genre
top_movies_df = pd.DataFrame(columns=movies_df.columns)

# %%
# Loop through each group and select the top 20 movies by rating which is in our data is IMDb
for group, data in grouped:
    if 'French' in group[1]:
        top_movies = data[data['IMDb'] > 8.0].sort_values(by='IMDb', ascending=False).head(20)
        top_movies_df = pd.concat([top_movies_df, top_movies])

# %%
top_movies_df
# Out:
#                                  Title  Year  Age  IMDb Rotten Tomatoes  \
# 790                          Inception  2010  13+   8.8             87%
# 5749                 Kill Bill: Vol. 1  2003  18+   8.1             85%
# 9851                             Queen  2013  13+   8.2             86%
# 2394   Monty Python and the Holy Grail  1975   7+   8.2             97%
# 1978              Inglourious Basterds  2009  18+   8.3             89%
# 2524                     The Lion King  1994  all   8.5             93%
# 6769                    The Green Mile  1999  18+   8.6             78%
# 827              It's a Wonderful Life  1946   7+   8.6             94%
# 1995        Portrait of a Lady on Fire  2019  18+   8.2             98%
# 10895                 Django Unchained  2012  18+   8.4             87%
#
#                        Directors                                    Genres  \
# 790            Christopher Nolan          Action,Adventure,Sci-Fi,Thriller
# 5749           Quentin Tarantino                     Action,Crime,Thriller
# 9851                  Vikas Bahl                    Adventure,Comedy,Drama
# 2394   Terry Gilliam,Terry Jones                  Adventure,Comedy,Fantasy
# 1978           Quentin Tarantino                       Adventure,Drama,War
# 2524                 Jon Favreau  Animation,Adventure,Drama,Family,Musical
# 6769              Frank Darabont               Crime,Drama,Fantasy,Mystery
# 827                  Frank Capra                      Drama,Family,Fantasy
# 1995              Céline Sciamma                             Drama,Romance
# 10895          Quentin Tarantino                             Drama,Western
#
#                             Country                             Language  \
# 790    United States,United Kingdom              English,Japanese,French
# 5749            United States,Japan              English,Japanese,French
# 9851                          India  Hindi,English,French,Japanese,Dutch
# 2394                 United Kingdom                 English,French,Latin
# 1978          Germany,United States        English,German,French,Italian
# 2524   United States,United Kingdom    English,Xhosa,Zulu,French,Spanish
# 6769                  United States                       English,French
# 827                   United States                       English,French
# 1995                         France                       French,Italian
# 10895                 United States        English,German,French,Italian
#
#        Runtime     ID Netflix Hulu Prime Video Disney+
# 790      148.0   6734       1    0           0       0
# 5749     111.0   7422       0    1           0       0
# 9851     146.0  10404       0    0           1       0
# 2394      91.0   8927       1    0           0       0
# 1978     153.0   6772       1    0           0       0
# 2524     118.0  14013       0    0           0       1
# 6769     189.0  13612       0    1           0       0
# 827      130.0   6933       0    0           1       0
# 1995     122.0  10233       0    1           0       0
# 10895    165.0   4136       1    0           0       0

# %% [markdown]
# 4. Analyse the genre distribution in French-language movies:

# %%
import matplotlib.pyplot as plt

# %%
# Filter the data frame to only include French-language movies
french_movies_df = movies_df[movies_df['Language'] == 'French']

# %%
# Count the number of movies in each genre
genre_counts = french_movies_df['Genres'].value_counts()

# %%
# Create a bar chart of the genre distribution
plt.bar(genre_counts.index, genre_counts.values)
plt.xticks(rotation=90)
plt.xlabel('Genres')
plt.ylabel('Number of Movies')
plt.title('Genre Distribution in French-Language Movies')
plt.show()

# %% [markdown]
# Conclusion and Insights:
# Based on the analysis we have conducted; we can draw the following conclusions and insights:
# The top-rated French-language movies across all genres are dominated by drama, comedy, and romance genres.
# Other genres such as crime, thriller, and action also have a significant presence in the top-rated French-language movies.
# Canopy can focus on curating a selection of top-rated French-language movies across various genres to cater to viewers of all age groups.
# Canopy can also use the insights gained from the genre distribution analysis to identify the least tapped genres and provide filmmakers with data to make original content in those genres.
# These conclusions and insights can help Canopy make informed decisions about the content they offer and cater to their target audience effectively.
